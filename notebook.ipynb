# %% [markdown]
# # ARTIDIS NLP Challenge A

# %%
import sys

# Check Python version. knowledge-graph-maker library requires >= 3.11.0 version.
if sys.version_info >= (3, 11):
    print(f"Python version is {sys.version}. You're running Python 3.11.0 or above.")
else:
    raise RuntimeError(f"Python 3.11.0 or above is required. You're running {sys.version}.")
# Out:
# Python version is 3.11.0 | packaged by conda-forge | (main, Oct 25 2022, 06:12:32) [MSC v.1929 64 bit (AMD64)]. You're running Python 3.11.0 or above.

# %%
# !pip install sentence-transformers
# !pip install tiktoken
# !pip install knowledge-graph-maker
# !pip install pyvis
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: sentence-transformers in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (3.1.1)
# Requirement already satisfied: transformers<5.0.0,>=4.38.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (2.4.1)
# Requirement already satisfied: scikit-learn in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (0.25.0)
# Requirement already satisfied: Pillow in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from huggingface-hub>=0.19.3->sentence-transformers) (4.12.2)
# Requirement already satisfied: sympy in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.3)
# Requirement already satisfied: networkx in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.3)
# Requirement already satisfied: jinja2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: colorama in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from transformers<5.0.0,>=4.38.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests->huggingface-hub>=0.19.3->sentence-transformers) (2024.8.30)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: tiktoken in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.26.0->tiktoken) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.26.0->tiktoken) (2024.8.30)
# Requirement already satisfied: knowledge-graph-maker in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (0.2.1)
# Requirement already satisfied: groq<0.7.0,>=0.6.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (0.6.0)
# Requirement already satisfied: jupyterlab<5.0.0,>=4.0.8 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (4.2.5)
# Requirement already satisfied: neo4j==5.19.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (5.19.0)
# Requirement already satisfied: neomodel<6.0.0,>=5.3.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (5.3.2)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.28.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (1.47.0)
# Requirement already satisfied: pathlib<2.0.0,>=1.0.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (1.0.1)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (1.0.1)
# Requirement already satisfied: uuid<2.0,>=1.30 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (1.30)
# Requirement already satisfied: yachalk<0.2.0,>=0.1.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from knowledge-graph-maker) (0.1.6)
# Requirement already satisfied: pytz in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from neo4j==5.19.0->knowledge-graph-maker) (2024.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (4.6.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from groq<0.7.0,>=0.6.0->knowledge-graph-maker) (4.12.2)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.0.4)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (3.1.4)
# Requirement already satisfied: jupyter-core in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (5.7.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.2.4)
# Requirement already satisfied: packaging in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (24.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (74.1.2)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (6.4.1)
# Requirement already satisfied: traitlets in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (5.14.3)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from openai<2.0.0,>=1.28.0->knowledge-graph-maker) (0.5.0)
# Requirement already satisfied: tqdm>4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from openai<2.0.0,>=1.28.0->knowledge-graph-maker) (4.66.5)
# Requirement already satisfied: importlib-resources in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from yachalk<0.2.0,>=0.1.5->knowledge-graph-maker) (6.4.5)
# Requirement already satisfied: idna>=2.8 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from anyio<5,>=3.5.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (3.10)
# Requirement already satisfied: certifi in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from httpx<1,>=0.23.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from httpx<1,>=0.23.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.8.5)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (8.27.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.6.0)
# Requirement already satisfied: psutil in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (6.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (26.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jinja2>=3.0.3->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.1.5)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-core->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-core->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (306)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pydantic<3,>=1.9.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pydantic<3,>=1.9.0->groq<0.7.0,>=0.6.0->knowledge-graph-maker) (2.23.4)
# Requirement already satisfied: colorama in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from tqdm>4->openai<2.0.0,>=1.28.0->knowledge-graph-maker) (0.4.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (21.2.0)
# Requirement already satisfied: decorator in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.6.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.2.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.8.4)
# Requirement already satisfied: fqdn in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (24.8.0)
# Requirement already satisfied: wcwidth in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.2.13)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (0.2.3)
# Requirement already satisfied: pycparser in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab<5.0.0,>=4.0.8->knowledge-graph-maker) (2.9.0.20240906)
# Requirement already satisfied: pyvis in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pyvis) (8.27.0)
# Requirement already satisfied: jinja2>=2.9.6 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pyvis) (3.1.4)
# Requirement already satisfied: jsonpickle>=1.4.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pyvis) (3.3.0)
# Requirement already satisfied: networkx>=1.11 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pyvis) (3.3)
# Requirement already satisfied: decorator in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (5.14.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (4.12.2)
# Requirement already satisfied: colorama in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from ipython>=5.3.0->pyvis) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jinja2>=2.9.6->pyvis) (2.1.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Requirement already satisfied: pandas in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\kbged\miniconda3\envs\artidis\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os
import re
import shutil
import subprocess
import datetime
import requests
import zipfile
import wget
import logging
import pkg_resources

import pandas as pd
import tiktoken
import torch
from sentence_transformers import SentenceTransformer, util
from IPython.core.interactiveshell import InteractiveShell
from dataclasses import dataclass
from pyvis.network import Network
import matplotlib.pyplot as plt
from knowledge_graph_maker import GraphMaker, Ontology, GroqClient, OpenAIClient, Document

InteractiveShell.ast_node_interactivity = "all"

# Adjust pandas options to display full content in the DataFrame
pd.set_option('display.max_colwidth', 20)
pd.set_option('display.max_rows', None)

# Initialize logger
logger = logging.getLogger(__name__)

# Save the key as an environment variable. Its free and gives enough token limit for this assignment. You can use any of the two API keys.
#os.environ['GROQ_API_KEY'] = "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"
os.environ['GROQ_API_KEY'] = "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"
# Out:
# C:\Users\kbged\AppData\Local\Temp\ipykernel_34644\202851862.py:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources

# %%
# Just for future reference.
def get_version(package_name):
    try:
        version = pkg_resources.get_distribution(package_name).version
        logger.info(f"{package_name} version: {version}")
    except pkg_resources.DistributionNotFound:
        logger.error(f"{package_name} is not installed.")

# List of packages to check
packages = [
    "sentence-transformers",
    "tiktoken",
    "knowledge-graph-maker",
    "pyvis",
    "pandas",
    "matplotlib"
]

# Check versions for each package
for package in packages:
    get_version(package)
# Out:
# INFO:__main__:sentence-transformers version: 3.1.1
# INFO:__main__:tiktoken version: 0.7.0
# INFO:__main__:knowledge-graph-maker version: 0.2.1
# INFO:__main__:pyvis version: 0.3.2
# INFO:__main__:pandas version: 2.2.3
# INFO:__main__:matplotlib version: 3.9.2

# %% [markdown]
# # Utility class and methods

# %%
# This cell contains all utility classes and functions for the assignment!

class InputParams:
    def __init__(self):
        self.emb_model = 'paraphrase-MiniLM-L6-v2'  # Default model name
        self.url        = 'https://www.dropbox.com/scl/fi/sb5v4fmadwwp2e3czlsb0/MedicalNewsToday.zip?rlkey=aep3jn98vk49f2bwtmhsvqzlt&st=plg438k5&dl=0'
        self.query_cancer = "Usage of biomarkers in diagnosis of cancer."
        self.keywords_cancer = [
            'biomarker', 'biomarkers', 'tissue', 'biopsy'
        ]
        self.mandatory_keywords_cancer = [
            'cancer', 'biomarker'
        ]

        self.query_ml = "Usage of machine learning or artificial intelligence in health care."
        self.keywords_ml = [
            'machine learning', ' AI ', ' ML ', '(ai)', '(ml)',
            'automation', 'nlp', 'computer vision',
            'artificial intelligence', 'deep learning',
            'text processing', 'processing of text',
            'lab report', 'patient experience'
        ]
        self.mandatory_keywords_ml = [
            # Add any mandatory keywords for ML here
        ]

        # Groq models
        self.gen_model = "mixtral-8x7b-32768"
        # self.groq_model = "llama3-8b-8192"
        # self.groq_model = "llama3-70b-8192"
        # self.groq_model = "gemma-7b-it"

        # OpenAI models
        #self.gen_model = "gpt-3.5-turbo"

        # Set the LLM Client (Groq or OpenAI)
        self.gen_client = GroqClient(model=self.gen_model, temperature=0.0, top_p=0.95)

class FileOps:
    @staticmethod
    def download_and_extract_medical_news(input_params: InputParams):
        """Download and extract the Medical News Today zip file."""
        try:
            # Check if wget is available
            if shutil.which("wget") is not None:
                subprocess.run(['wget', input_params.url], check=True)

            else:
                # Use curl to download the file
                subprocess.run(['curl', '-L', '-o', 'MedicalNewsToday.zip', input_params.url], check=True)

            # Check if the file was downloaded
            if os.path.exists('MedicalNewsToday.zip'):
                # Unzip the file
                with zipfile.ZipFile('MedicalNewsToday.zip', 'r') as zip_ref:
                    zip_ref.extractall('./')
                logger.info("Download and extraction completed successfully.")
            else:
                logger.warning("No zip file found.")

        except subprocess.CalledProcessError as e:
            logger.error(f"Error during file download: {e}")
        except zipfile.BadZipFile:
            logger.error("Error: The downloaded file is not a valid zip file.")
        except Exception as e:
            logger.error(f"An unexpected error occurred: {e}")

class InputOps:
    def __init__(self, input_params: InputParams):
        self.input_params = input_params
        logger.info("Initialized InputOps with input parameters.")

    def create_input_dataframe_from_articles(self):
        """Create a DataFrame from articles in the './articles/' folder."""
        articles_folder = './articles/'
        data = []

        # Initialize the tokenizer (using GPT-2 encoding)
        tokenizer = tiktoken.get_encoding("gpt2")
        logger.info("Initialized GPT-2 tokenizer.")

        # Loop through each file in the articles folder
        for file_name in os.listdir(articles_folder):
            if file_name.endswith('.txt'):
                #logger.info(f"Processing file: {file_name}")
                # Full path to the text file
                file_path = os.path.join(articles_folder, file_name)
                try:
                    # Read the content of the file
                    with open(file_path, 'r', encoding='utf-8') as file:
                        content = file.read()
                        # Count tokens using tiktoken
                        token_count = len(tokenizer.encode(content))
                        # Append the file name (without path), content, and token count to the data list
                        data.append((file_name, content, token_count))
                        #logger.info(f"File {file_name} processed with {token_count} tokens.")
                except Exception as e:
                    logger.error(f"Error reading file {file_name}: {e}")

        # Create a pandas DataFrame from the data list
        df = pd.DataFrame(data, columns=['file_name', 'content', 'token_count'])

        # Display the DataFrame
        logger.info("Displaying the first few rows of the DataFrame.")
        display(df.head())

        # Gives an idea of the approximate number of tokens in an article.
        logger.info("Calculating token statistics.")
        display(df.sort_values('token_count', ascending=False).agg({'token_count': ['max', 'mean', 'std', 'min']}))

        return df



class ProcOps:
    def __init__(self, input_params: InputParams):
        self.input_params = input_params
        logger.info("Initialized ProcOps with input parameters.")

    def generate_doc_embeddings(self, df: pd.DataFrame):
        """Generate embeddings for documents in a DataFrame."""
        if 'content' not in df:
            logger.error("DataFrame must contain a 'content' column with documents.")
            raise ValueError("DataFrame must contain a 'content' column with documents.")
        
        logger.info("Loading the pre-trained model.")
        # Load the pre-trained model
        self.model = SentenceTransformer(self.input_params.emb_model)

        logger.info("Extracting document content and computing embeddings.")
        # Extract document content and compute embeddings
        docs = df['content'].tolist()
        embeddings = self.model.encode(docs, convert_to_tensor=True)
        logger.info("Document embeddings generated successfully.")
        return embeddings

    def find_keywords(self, text, keywords):
        #logger.info("Finding keywords in the provided text.")
        matched_keywords = []
        for keyword in keywords:
            if keyword in [" ML ", " AI "]:  # Case-sensitive match for "ml"
                if re.search(rf'\b{re.escape(keyword)}\b', text):
                    matched_keywords.append(keyword)
            else:  # Case-insensitive match for other keywords
                if re.search(rf'\b{re.escape(keyword)}\b', text, re.IGNORECASE):
                    matched_keywords.append(keyword)
        logger.debug(f"Matched keywords: {matched_keywords}")
        return list(set(matched_keywords))

    def process_df(self, df, doc_embeddings, query, keywords, mandatory_keywords):
        logger.info("Processing DataFrame with document embeddings.")
        # Encode the query using the model
        query_embedding = self.model.encode(query, convert_to_tensor=True)

        logger.info("Calculating cosine similarity between the query and documents.")
        # Calculate cosine similarity between the query and the documents
        similarities = util.pytorch_cos_sim(query_embedding, doc_embeddings)

        # Update the DataFrame with similarity scores and keyword matches
        df['similarity_score'] = similarities[0].tolist()
        df['matched_keywords'] = df['content'].apply(lambda text: self.find_keywords(text, keywords))
        df['unique_keyword_count'] = df['matched_keywords'].apply(len)

        logger.info("Counting occurrences of the word 'cancer' in the articles.")
        # Count the number of times the word 'cancer' is used in each article
        df['cancer_count'] = df['content'].str.lower().str.count('cancer')

        # Calculate average cancer keyword density
        df['avg_cancer_keyword'] = (df['cancer_count'] * 100 / df['token_count']).round(1)

        logger.info("Checking for mandatory keywords in each document.")
        # Check if all mandatory keywords are present in the document
        df['mandatory_keywords_present'] = df['content'].apply(lambda text: all(
            keyword.lower() in text.lower() for keyword in mandatory_keywords
        ))

        logger.info("Sorting the DataFrame by similarity score.")
        # Sort the DataFrame by similarity score
        df = df.sort_values(by='similarity_score', ascending=False).reset_index(drop=True)

        logger.info("Counting keyword occurrences across documents.")
        # Create a dictionary to track keyword occurrences across documents
        keyword_doc_count = {keyword: 0 for keyword in keywords}

        # Count how many documents each keyword appears in
        for index, row in df.iterrows():
            for keyword in row['matched_keywords']:
                keyword_doc_count[keyword] += 1

        # Create a DataFrame from the keyword_doc_count dictionary
        keyword_df = pd.DataFrame(list(keyword_doc_count.items()), columns=['keyword', 'document_count'])

        logger.info("Processing completed successfully.")
        return df, keyword_df

class KGOps:
    def __init__(self, ontology, website_name):
        self.ontology = ontology
        self.website_name = website_name
        logger.info("Initialized KGOps with ontology and website name.")

    def generate_color_map(self, ontology_labels):
        logger.info("Generating color map for ontology labels.")
        cmap = plt.get_cmap('tab10')  # Colormap for distinct colors
        colors = [cmap(i) for i in range(len(ontology_labels))]
        hex_colors = ['#%02x%02x%02x' % (int(r*255), int(g*255), int(b*255)) for r, g, b, _ in colors]
        logger.info("Color map generated successfully.")
        return {label: hex_color for label, hex_color in zip(ontology_labels, hex_colors)}

    def extract_labels_from_ontology(self):
        logger.info("Extracting labels from ontology.")
        labels = [list(label.keys())[0] for label in self.ontology.labels]
        logger.debug(f"Extracted labels: {labels}")
        return labels

    def plot_knowledge_graph(self, edges, notebook=False):
        logger.info("Plotting the knowledge graph.")
        # Extract labels from the ontology
        ontology_labels = self.extract_labels_from_ontology()

        net = Network(notebook=notebook)

        # Generate color map for ontology labels
        label_color_map = self.generate_color_map(ontology_labels)

        # Set a default color for non-ontology labels
        default_color = '#CCCCCC'

        # Add nodes and edges to the network
        for edge in edges:
            # Assign color based on the ontology label
            color_node_1 = label_color_map.get(edge.node_1.label, default_color)
            color_node_2 = label_color_map.get(edge.node_2.label, default_color)

            # Add nodes with color
            net.add_node(edge.node_1.name, label=edge.node_1.name, title=edge.node_1.label, color=color_node_1)
            net.add_node(edge.node_2.name, label=edge.node_2.name, title=edge.node_2.label, color=color_node_2)

            # Add edge with the relationship as the title
            net.add_edge(edge.node_1.name, edge.node_2.name, title=edge.relationship)

        # Create a legend for ontology labels
        legend_html = '<div style="position: absolute; bottom: 10px; left: 10px; background: white; padding: 10px; border: 1px solid black; z-index: 1000;">'
        legend_html += '<strong>Legend:</strong><br>'
        for label, color in label_color_map.items():
            legend_html += f'<div style="color: {color};">● {label}</div>'
        legend_html += '</div>'

        logger.info(f"Showing network graph and saving as {self.website_name}.")
        net.show(self.website_name)

        # Append the legend to the HTML file with UTF-8 encoding
        with open(self.website_name, "a", encoding="utf-8") as f:
            f.write(legend_html)
            logger.info("Legend appended to the HTML file.")

# %% [markdown]
# # Data ingestion

# %%
# Initialize the input parameters
input_params = InputParams()

# %%
# Download and extract files
FileOps.download_and_extract_medical_news(input_params)
# Out:
# INFO:__main__:Download and extraction completed successfully.

# %%
# Initialize InputOps
input_ops = InputOps(input_params)

# Create the DataFrame of articles
df_input = input_ops.create_input_dataframe_from_articles()
# Out:
# INFO:__main__:Initialized InputOps with input parameters.
# INFO:__main__:Initialized GPT-2 tokenizer.
# INFO:__main__:Displaying the first few rows of the DataFrame.
#   file_name              content  token_count
# 0     1.txt  A new study, pub...          520
# 1    10.txt  A woman consider...         1199
# 2   100.txt  Ventolin HFA is ...         9205
# 3  1000.txt  Candida auris is...         1261
# 4  1001.txt  New research sug...          892
# INFO:__main__:Calculating token statistics.
#        token_count
# max   23317.000000
# mean   1485.389140
# std    1330.357188
# min     191.000000

# %% [markdown]
# # Step 1 as defined in the document sent with the email (Skim articles to keep only relevant articles for the two Themes).

# %%
# Initialize ProcOps
proc_ops = ProcOps(input_params)

# Generate document embeddings of each article
doc_embeddings = proc_ops.generate_doc_embeddings(df_input)
# Out:
# INFO:__main__:Initialized ProcOps with input parameters.
# INFO:__main__:Loading the pre-trained model.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: paraphrase-MiniLM-L6-v2
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# C:\Users\kbged\Miniconda3\envs\artidis\Lib\site-packages\huggingface_hub\file_download.py:147: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\kbged\.cache\huggingface\hub\models--sentence-transformers--paraphrase-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.73k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# C:\Users\kbged\Miniconda3\envs\artidis\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# INFO:__main__:Extracting document content and computing embeddings.
# Batches:   0%|          | 0/63 [00:00<?, ?it/s]
# INFO:__main__:Document embeddings generated successfully.

# %%
# Update input df for each of the two themes described in the document sent with the email. (For example, df_cancer contains the 4 metrics described in the document for theme 1 while df_keyword_cancer gives the number of articles having keywords.)
df_cancer, df_keyword_cancer = proc_ops.process_df(df_input, doc_embeddings, input_params.query_cancer, input_params.keywords_cancer, input_params.mandatory_keywords_cancer)
df_ml, df_keyword_ml = proc_ops.process_df(df_input, doc_embeddings, input_params.query_ml, input_params.keywords_ml, input_params.mandatory_keywords_ml)
# Out:
# INFO:__main__:Processing DataFrame with document embeddings.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# INFO:__main__:Calculating cosine similarity between the query and documents.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# ...
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Finding keywords in the provided text.
# INFO:__main__:Counting occurrences of the word 'cancer' in the articles.
# INFO:__main__:Checking for mandatory keywords in each document.
# INFO:__main__:Sorting the DataFrame by similarity score.
# INFO:__main__:Counting keyword occurrences across documents.
# INFO:__main__:Processing completed successfully.

# %%
df_keyword_cancer
df_cancer_skim = df_cancer.loc[#(df_cancer['cancer_count']>0)&
                               #(df_cancer['similarity_score']>0.00)|
                               #((df_cancer['unique_keyword_count']>0)&(df_cancer['avg_cancer_keyword']>3.0))&
                               (df_cancer['mandatory_keywords_present']==True)
                               ].reset_index(drop=True)

df_cancer_skim

#Input for knowledge graph of theme 1
df_cancer_list = df_cancer_skim['content'].tolist()
# Out:
#       keyword  document_count
# 0   biomarker              12
# 1  biomarkers              23
# 2      tissue             500
# 3      biopsy             108
#    file_name              content  token_count  similarity_score  \
# 0    780.txt  New research use...          884          0.530929
# 1   1136.txt  Some types of ca...         1032          0.504091
# 2    199.txt  It turns out som...          856          0.351578
# 3   1246.txt  Imagine a future...         1865          0.348968
# 4   1839.txt  Researchers have...          738          0.330005
# 5   1341.txt  A new pilot stud...          941          0.325977
# 6   1221.txt  Nilotinib, a dru...         1423          0.306921
# 7    772.txt  Scientists have ...         1009          0.270634
# 8     75.txt  The results of s...          848          0.230521
# 9   1456.txt  A new study sugg...          633          0.128483
# 10  1515.txt  If you buy somet...         2310          0.125551
# 11   890.txt  A team at Stanfo...         1069          0.093356
# 12  1082.txt  If you buy somet...         1198          0.006438
#
#        matched_keywords  unique_keyword_count  cancer_count  \
# 0           [biomarker]                    1              9
# 1          [biomarkers]                    1             20
# 2          [biomarkers]                    1             21
# 3          [biomarkers]                    1             14
# 4           [biomarker]                    1             19
# 5   [biomarker, biop...                    3             14
# 6   [tissue, biomark...                    2              1
# 7           [biomarker]                    1             10
# 8          [biomarkers]                    1              1
# 9          [biomarkers]                    1              2
# 10  [biomarker, tiss...                    3              2
# 11  [tissue, biomark...                    2              2
# 12         [biomarkers]                    1              1
#
#     avg_cancer_keyword  mandatory_keywords_present
# 0                  1.0                 True
# 1                  1.9                 True
# 2                  2.5                 True
# 3                  0.8                 True
# 4                  2.6                 True
# 5                  1.5                 True
# 6                  0.1                 True
# 7                  1.0                 True
# 8                  0.1                 True
# 9                  0.3                 True
# 10                 0.1                 True
# 11                 0.2                 True
# 12                 0.1                 True

# %%
df_keyword_ml
df_ml_skim = df_ml.loc[#(df_ml['cancer_count']>0)&
                       #(df_ml['similarity_score']>0.00)|
                       (df_ml['unique_keyword_count']>0)
                       #&
                       #(df_ml['avg_cancer_keyword']>3.0))&
                       #(df_ml['mandatory_keywords_present']==True)
                       ].reset_index(drop=True)

df_ml_skim

#Input for knowledge graph of theme 1
df_ml_list = df_ml_skim['content'].tolist()
# Out:
#                 keyword  document_count
# 0      machine learning              11
# 1                   AI                6
# 2                   ML                0
# 3                  (ai)               0
# 4                  (ml)               0
# 5            automation               0
# 6                   nlp               0
# 7       computer vision               1
# 8   artificial intel...              12
# 9         deep learning               2
# 10      text processing               0
# 11   processing of text               0
# 12           lab report               0
# 13   patient experience               1
#    file_name              content  token_count  similarity_score  \
# 0   1307.txt  New research tha...          813          0.670913
# 1    893.txt  The first system...          918          0.609950
# 2    767.txt  Researchers have...          806          0.486370
# 3   1245.txt  For some, the wo...         1115          0.412014
# 4    888.txt  New research sho...          872          0.375085
# 5   1537.txt  People’s languag...         1284          0.370376
# 6    982.txt  Scientists have ...         1124          0.358907
# 7    908.txt  Effective commun...         1428          0.339175
# 8    615.txt  A new study has ...          814          0.286948
# 9   1248.txt  Scientists have ...         1071          0.237351
# 10   116.txt  Empathy helps us...          809          0.219487
# 11   765.txt  The first experi...          875          0.203872
# 12   532.txt  A study that com...          956          0.183371
# 13   949.txt  When melanoma sp...          914          0.175398
# 14  1411.txt  Lung cancer is a...          863          0.169216
# 15   524.txt  Scientists have ...          963          0.145714
# 16  1234.txt  Following a stro...         1647          0.126995
# 17  1965.txt  How is it that c...         1110          0.058722
# 18  1931.txt  A genetic study ...          709          0.043780
#
#        matched_keywords  unique_keyword_count  cancer_count  \
# 0   [deep learning, ...                    4              1
# 1   [deep learning, ...                    3              1
# 2   [artificial inte...                    2              0
# 3    [machine learning]                    1              0
# 4   [artificial inte...                    2              0
# 5   [machine learnin...                    2              0
# 6   [machine learnin...                    3              0
# 7   [patient experie...                    1              0
# 8   [machine learnin...                    2             16
# 9    [machine learning]                    1              1
# 10   [machine learning]                    1              0
# 11   [machine learning]                    1              1
# 12  [machine learnin...                    2              0
# 13  [artificial inte...                    1              9
# 14  [artificial inte...                    2             21
# 15  [artificial inte...                    1              0
# 16  [computer vision...                    2              0
# 17  [artificial inte...                    1              0
# 18   [machine learning]                    1              0
#
#     avg_cancer_keyword  mandatory_keywords_present
# 0                  0.1                 True
# 1                  0.1                 True
# 2                  0.0                 True
# 3                  0.0                 True
# 4                  0.0                 True
# 5                  0.0                 True
# 6                  0.0                 True
# 7                  0.0                 True
# 8                  2.0                 True
# 9                  0.1                 True
# 10                 0.0                 True
# 11                 0.1                 True
# 12                 0.0                 True
# 13                 1.0                 True
# 14                 2.4                 True
# 15                 0.0                 True
# 16                 0.0                 True
# 17                 0.0                 True
# 18                 0.0                 True

# %% [markdown]
# # Step 2 as defined in the document sent with the email (Make Knowledge Graph for the two Themes)

# %%
ontology_cancer = Ontology(
    labels=[
        {"Cancer Type": "Include only specific type of cancer, for example, lymphocytic leukemia, breast cancer, etc. Do not include other diseases like diabetes, etc which are not cancer."},
        {"Cancer": "Include when cancer is addressed in general without specification of any specific type of cancer such as breast cancer, leukemia, etc."},
        {"Biomarker for Cancer Diagnosis": "Include only when using biomarkers for cancer diagnosis, otherwise do not include it"},
        {"Tissue used for cancer diagnosis": "Include only when using any tissue in cancer diagnosis. If the tissue is not involved in cancer diagnosis, do NOT include it. Tissue should be related to humans."},
        {"Tissue affected by cancer": "Include only when human tissue is affected during cancer, otherwise do not include it"},
        {"Cancer Diagnosis Method": "Include only when a particular method is used for cancer diagnosis, otherwise do not include it"},
        {"Cancer Diagnosis Device/Tool": "Include only when a device is used for cancer diagnosis, otherwise do not include it"},
        {"Cancer Diagnosis Technology": "Include only when a particular technology is used for cancer diagnosis, otherwise do not include it"},
        {"Drugs": "Include only when using drugs for cancer diagnosis, otherwise do not include it"},
        {"New Research of Cancer Diagnosis Method": "Include only when a new method or research is used/developed for cancer diagnosis. Do not include methods which not used in cancer diagnosis."}
    ],
    relationships=[
        "Relation between any pair of Entities present in the text",
        ],
)

# %%
current_time = str(datetime.datetime.now())

graph_maker_cancer = GraphMaker(ontology=ontology_cancer, llm_client=input_params.gen_client, verbose=False)

docs_cancer = map(
    lambda t: Document(text=t, metadata={'generated_at': current_time}),
    df_cancer_list
)

graph_cancer = graph_maker_cancer.from_documents(
    list(docs_cancer),
    delay_s_between=15 ## delay_s_between because otherwise groq api maxes out pretty fast.
    )

print("Total number of Edges", len(graph_cancer))

kg_cancer = KGOps(ontology_cancer, "knowledge_graph_cancer_biomarkers.html")
kg_cancer.plot_knowledge_graph(graph_cancer, notebook=True)
# Out:
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:07 - INFO
# Document: 1
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:07 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Include only specific type of cancer, for example, lymphocytic leukemia, breast cancer, etc. Do not include other diseases like diabetes, etc which are not cancer.'}, {'Cancer': 'Include when cancer is addressed in general without specification of any specific type of cancer such as breast cancer, leukemia, etc.'}, {'Biomarker for Cancer Diagnosis': 'Include only when using biomarkers for cancer diagnosis, otherwise do not include it'}, {'Tissue used for cancer diagnosis': 'Include only when using any tissue in cancer diagnosis. If the tissue is not involved in cancer diagnosis, do NOT include it. Tissue should be related to humans.'}, {'Tissue affected by cancer': 'Include only when human tissue is affected during cancer, otherwise do not include it'}, {'Cancer Diagnosis Method': 'Include only when a particular method is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Device/Tool': 'Include only when a device is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Technology': 'Include only when a particular technology is used for cancer diagnosis, otherwise do not include it'}, {'Drugs': 'Include only when using drugs for cancer diagnosis, otherwise do not include it'}, {'New Research of Cancer Diagnosis Method': 'Include only when a new method or research is used/developed for cancer diagnosis. Do not include methods which not used in cancer diagnosis.'}] relationships=['Relation between any pair of Entities present in the text']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:08 - INFO
# LLM Response:
# [
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "new research using nanosensors to detect protein-to-protein interactions"},
#  "node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "protein-to-protein interactions"},
#  "relationship": "The new research uses nanosensors to detect protein-to-protein interactions which are being used as a biomarker for cancer diagnosis."},
#
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "new research using nanosensors to detect protein-to-protein interactions"},
#  "node_2": {"label": "Cancer Type", "name": "lymphocytic leukemia"},
#  "relationship": "The new research using nanosensors to detect protein-to-protein interactions is particularly helpful for detecting lymphocytic leukemia, a form of cancer that starts in the bone marrow and spreads into the blood."},
#
# {"node_1": {"label": "Cancer", "name": "cancer"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that cancer is one of the leading causes of death both in the United States and worldwide."},
#
# {"node_1": {"label": "Cancer", "name": "cancer"},
#  "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "relationship": "The text mentions that new research uses nanosensors to detect cancer."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cells"},
#  "relationship": "The nanosensors are used to detect protein-to-protein interactions in cells, which are affected by cancer."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "cell membrane"},
#  "relationship": "The nanosensors create a small opening in the cell membrane through which electric current passes."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Drugs"},
#  "relationship": "The text mentions that the nanosensors may be useful for biomarker screening, protein profiling, and the large-scale study of proteins (known as proteomics)."},
#
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "nanopores"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that the nanosensors bypass the obstacle of detecting fleeting protein-to-protein interactions by creating a small opening in the cell membrane through which electric current passes, known as nanopores."},
#
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "interactomics"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that interactomics is a flourishing subfield of biophysics that studies the consequences of protein-to-protein interactions."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:08 - INFO
# Trying JSON Parsing:
# [
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "new research using nanosensors to detect protein-to-protein interactions"},
#  "node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "protein-to-protein interactions"},
#  "relationship": "The new research uses nanosensors to detect protein-to-protein interactions which are being used as a biomarker for cancer diagnosis."},
#
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "new research using nanosensors to detect protein-to-protein interactions"},
#  "node_2": {"label": "Cancer Type", "name": "lymphocytic leukemia"},
#  "relationship": "The new research using nanosensors to detect protein-to-protein interactions is particularly helpful for detecting lymphocytic leukemia, a form of cancer that starts in the bone marrow and spreads into the blood."},
#
# {"node_1": {"label": "Cancer", "name": "cancer"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that cancer is one of the leading causes of death both in the United States and worldwide."},
#
# {"node_1": {"label": "Cancer", "name": "cancer"},
#  "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "relationship": "The text mentions that new research uses nanosensors to detect cancer."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cells"},
#  "relationship": "The nanosensors are used to detect protein-to-protein interactions in cells, which are affected by cancer."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "cell membrane"},
#  "relationship": "The nanosensors create a small opening in the cell membrane through which electric current passes."},
#
# {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "nanosensors"},
#  "node_2": {"label": "Drugs"},
#  "relationship": "The text mentions that the nanosensors may be useful for biomarker screening, protein profiling, and the large-scale study of proteins (known as proteomics)."},
#
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "nanopores"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that the nanosensors bypass the obstacle of detecting fleeting protein-to-protein interactions by creating a small opening in the cell membrane through which electric current passes, known as nanopores."},
#
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "interactomics"},
#  "node_2": {"label": "None"},
#  "relationship": "The text mentions that interactomics is a flourishing subfield of biophysics that studies the consequences of protein-to-protein interactions."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:08 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER ERROR - 2024-09-23 07:54:08 - INFO
# Failed to parse the Edge:
# [{'type': 'missing', 'loc': ('node_2', 'name'), 'msg': 'Field required'}]
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:08 - INFO
# FAULTY EDGE: {'node_1': {'label': 'Cancer', 'name': 'cancer'}, 'node_2': {'label': 'None'}, 'relationship': 'The text mentions that cancer is one of the leading causes of death both in the United States and worldwide.'}
#
#
# ▶︎ GRAPH MAKER ERROR - 2024-09-23 07:54:09 - INFO
# Failed to parse the Edge:
# [{'type': 'missing', 'loc': ('node_2', 'name'), 'msg': 'Field required'}]
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:09 - INFO
# FAULTY EDGE: {'node_1': {'label': 'Cancer Diagnosis Device/Tool', 'name': 'nanosensors'}, 'node_2': {'label': 'Drugs'}, 'relationship': 'The text mentions that the nanosensors may be useful for biomarker screening, protein profiling, and the large-scale study of proteins (known as proteomics).'}
#
#
# ▶︎ GRAPH MAKER ERROR - 2024-09-23 07:54:09 - INFO
# Failed to parse the Edge:
# [{'type': 'missing', 'loc': ('node_2', 'name'), 'msg': 'Field required'}]
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:09 - INFO
# FAULTY EDGE: {'node_1': {'label': 'Cancer Diagnosis Technology', 'name': 'nanopores'}, 'node_2': {'label': 'None'}, 'relationship': 'The text mentions that the nanosensors bypass the obstacle of detecting fleeting protein-to-protein interactions by creating a small opening in the cell membrane through which electric current passes, known as nanopores.'}
#
#
# ▶︎ GRAPH MAKER ERROR - 2024-09-23 07:54:09 - INFO
# Failed to parse the Edge:
# [{'type': 'missing', 'loc': ('node_2', 'name'), 'msg': 'Field required'}]
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:09 - INFO
# FAULTY EDGE: {'node_1': {'label': 'Cancer Diagnosis Technology', 'name': 'interactomics'}, 'node_2': {'label': 'None'}, 'relationship': 'The text mentions that interactomics is a flourishing subfield of biophysics that studies the consequences of protein-to-protein interactions.'}
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:09 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:24 - INFO
# Document: 2
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:24 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Include only specific type of cancer, for example, lymphocytic leukemia, breast cancer, etc. Do not include other diseases like diabetes, etc which are not cancer.'}, {'Cancer': 'Include when cancer is addressed in general without specification of any specific type of cancer such as breast cancer, leukemia, etc.'}, {'Biomarker for Cancer Diagnosis': 'Include only when using biomarkers for cancer diagnosis, otherwise do not include it'}, {'Tissue used for cancer diagnosis': 'Include only when using any tissue in cancer diagnosis. If the tissue is not involved in cancer diagnosis, do NOT include it. Tissue should be related to humans.'}, {'Tissue affected by cancer': 'Include only when human tissue is affected during cancer, otherwise do not include it'}, {'Cancer Diagnosis Method': 'Include only when a particular method is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Device/Tool': 'Include only when a device is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Technology': 'Include only when a particular technology is used for cancer diagnosis, otherwise do not include it'}, {'Drugs': 'Include only when using drugs for cancer diagnosis, otherwise do not include it'}, {'New Research of Cancer Diagnosis Method': 'Include only when a new method or research is used/developed for cancer diagnosis. Do not include methods which not used in cancer diagnosis.'}] relationships=['Relation between any pair of Entities present in the text']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:25 - INFO
# LLM Response:
# [
#  {"node_1": {"label": "Cancer Type", "name": "ovarian cancer"},
#  "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "3-D-nanopatterned microfluidic chip"},
#  "relationship": "The 3-D-nanopatterned microfluidic chip is a device used for diagnosing ovarian cancer."},
#
#  {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "3-D-nanopatterned microfluidic chip"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The 3-D-nanopatterned microfluidic chip uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Cancer", "name": "notoriously hard to detect cancers"},
#  "node_2": {"label": "Cancer Type", "name": "ovarian cancer"},
#  "relationship": "Ovarian cancer is an example of a hard-to-detect cancer."},
#
#  {"node_1": {"label": "Biomarker for Cancer Diagnosis", "name": "exosomes"},
#  "node_2": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "relationship": "The method of diagnosing cancer involves filtering for exosomes, which are biomarkers for cancer diagnosis."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cancer cells"},
#  "relationship": "The method of filtering for exosomes identifies and diagnoses cancer by analyzing the exosomes produced by cancer cells."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The method of filtering for exosomes uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Cancer Diagnosis Technology", "name": "3-D nanoporous herringbone structure"},
#  "node_2": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "relationship": "The method of mass transfer in cancer diagnosis uses the 3D nanoporous herringbone structure technology."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cancer cells"},
#  "relationship": "The method of mass transfer identifies and diagnoses cancer by analyzing the exosomes produced by cancer cells."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The method of mass transfer uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Drugs", "name": "not mentioned"},
#  "node_2": {"label": "Cancer Diagnosis", "name": "not mentioned"},
#  "relationship": "The text does not mention any drugs or cancer diagnosis."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:25 - INFO
# Trying JSON Parsing:
# [
#  {"node_1": {"label": "Cancer Type", "name": "ovarian cancer"},
#  "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "3-D-nanopatterned microfluidic chip"},
#  "relationship": "The 3-D-nanopatterned microfluidic chip is a device used for diagnosing ovarian cancer."},
#
#  {"node_1": {"label": "Cancer Diagnosis Device/Tool", "name": "3-D-nanopatterned microfluidic chip"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The 3-D-nanopatterned microfluidic chip uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Cancer", "name": "notoriously hard to detect cancers"},
#  "node_2": {"label": "Cancer Type", "name": "ovarian cancer"},
#  "relationship": "Ovarian cancer is an example of a hard-to-detect cancer."},
#
#  {"node_1": {"label": "Biomarker for Cancer Diagnosis", "name": "exosomes"},
#  "node_2": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "relationship": "The method of diagnosing cancer involves filtering for exosomes, which are biomarkers for cancer diagnosis."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cancer cells"},
#  "relationship": "The method of filtering for exosomes identifies and diagnoses cancer by analyzing the exosomes produced by cancer cells."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "filtering for exosomes"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The method of filtering for exosomes uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Cancer Diagnosis Technology", "name": "3-D nanoporous herringbone structure"},
#  "node_2": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "relationship": "The method of mass transfer in cancer diagnosis uses the 3D nanoporous herringbone structure technology."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "node_2": {"label": "Tissue affected by cancer", "name": "cancer cells"},
#  "relationship": "The method of mass transfer identifies and diagnoses cancer by analyzing the exosomes produced by cancer cells."},
#
#  {"node_1": {"label": "Cancer Diagnosis Method", "name": "mass transfer"},
#  "node_2": {"label": "Tissue used for cancer diagnosis", "name": "plasma"},
#  "relationship": "The method of mass transfer uses plasma, a component of blood, for diagnosing cancer."},
#
#  {"node_1": {"label": "Drugs", "name": "not mentioned"},
#  "node_2": {"label": "Cancer Diagnosis", "name": "not mentioned"},
#  "relationship": "The text does not mention any drugs or cancer diagnosis."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:25 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:25 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:40 - INFO
# Document: 3
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:40 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Include only specific type of cancer, for example, lymphocytic leukemia, breast cancer, etc. Do not include other diseases like diabetes, etc which are not cancer.'}, {'Cancer': 'Include when cancer is addressed in general without specification of any specific type of cancer such as breast cancer, leukemia, etc.'}, {'Biomarker for Cancer Diagnosis': 'Include only when using biomarkers for cancer diagnosis, otherwise do not include it'}, {'Tissue used for cancer diagnosis': 'Include only when using any tissue in cancer diagnosis. If the tissue is not involved in cancer diagnosis, do NOT include it. Tissue should be related to humans.'}, {'Tissue affected by cancer': 'Include only when human tissue is affected during cancer, otherwise do not include it'}, {'Cancer Diagnosis Method': 'Include only when a particular method is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Device/Tool': 'Include only when a device is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Technology': 'Include only when a particular technology is used for cancer diagnosis, otherwise do not include it'}, {'Drugs': 'Include only when using drugs for cancer diagnosis, otherwise do not include it'}, {'New Research of Cancer Diagnosis Method': 'Include only when a new method or research is used/developed for cancer diagnosis. Do not include methods which not used in cancer diagnosis.'}] relationships=['Relation between any pair of Entities present in the text']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:54:45 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Drugs", "name": "approved, safe drugs"},
# "node_2": {"label": "Cancer", "name": "anticancer properties"},
# "relationship": "Some approved, safe drugs have unexpected anticancer properties."},
#
# {"node_1": {"label": "Drug", "name": "a drug developed to treat one condition"},
# "node_2": {"label": "Cancer", "name": "value in treating another"},
# "relationship": "Occasionally, researchers find that a drug developed to treat one condition has unexpected value in treating another."},
#
# {"node_1": {"label": "Drug", "name": "pain reliever aspirin"},
# "node_2": {"label": "Cancer", "name": "prevents cardiovascular disease"},
# "relationship": "A well-known case in point is the pain reliever aspirin, which turns out to be of use in preventing cardiovascular disease."},
#
# {"node_1": {"label": "Researchers", "name": "researchers"},
# "node_2": {"label": "Drug compounds", "name": "thousands of drug compounds"},
# "relationship": "Researchers have taken a fresh look at thousands of drug compounds"},
#
# {"node_1": {"label": "Drug compounds", "name": "nearly 50 approved drug compounds"},
# "node_2": {"label": "Cancer", "name": "cancer-fighting capabilities"},
# "relationship": "The investigation concludes that nearly 50 approved drug compounds have previously unrecognized cancer-fighting capabilities."},
#
# {"node_1": {"label": "Dr Todd Golub", "name": "Dr Todd Golub"},
# "node_2": {"label": "Cancer", "name": "anticipation of finding even a single compound with anticancer properties"},
# "relationship": "He is the senior investigator of the study, which is summarized in the journal Nature Cancer. He says, ‘We thought we’d be lucky if we found even a single compound with anticancer properties'"},
#
# {"node_1": {"label": "Broad Institute", "name": "The Broad Institute"},
# "node_2": {"label": "Drug Repurposing Hub", "name": "Drug Repurposing Hub"},
# "relationship": "The Broad Institute’s Drug Repurposing Hub is a massive database designed to help researchers find new uses for already approved compounds."},
#
# {"node_1": {"label": "Dr Steven Corsello", "name": "Dr Steven Corsello"},
# "node_2": {"label": "Drug Repurposing Hub", "name": "Drug Repurposing Hub"},
# "relationship": "The first author of the study, Dr Steven Corsello, the founder of the hub and an oncologist at Dana-Farber, says"},
#
# {"node_1": {"label": "Researchers", "name": "researchers"},
# "node_2": {"label": "Drug compounds", "name": "4,518 drugs"},
# "relationship": "The researchers tested 4,518 drugs"},
#
# {"node_1": {"label": "Drug compounds", "name": "578 human cancer cell lines"},
# "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "Cancer Cell Line Encyclopedia"},
# "relationship": "The researchers tested 4,518 drugs on 578 human cancer cell lines from the Broad Institute’s Cancer Cell Line Encyclopedia."},
#
# {"node_1": {"label": "Dr Golub's lab", "name": "Dr Golub's lab"},
# "node_2": {"label": "Molecular method", "name": "PRISM"},
# "relationship": "Dr Golub’s lab had developed a molecular method called PRISM"},
#
# {"node_1": {"label": "PRISM", "name": "PRISM"},
# "node_2": {"label": "Tissue used for cancer diagnosis", "name": "DNA barcode"},
# "relationship": "Dr Golub’s lab had developed a molecular method called PRISM that tags each cell line with a DNA barcode"},
#
# {"node_1": {"label": "DNA barcode", "name": "DNA barcode"},
# "node_2": {"label": "Cancer Diagnosis Method", "name": "pooling several cell lines in a single dish"},
# "relationship": "The barcodes sped up the testing by allowing the researchers to pool several cell lines in a single dish without losing the ability to track the survival rate of each as it reacted to a drug compound."},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Cancer", "name": "cancer cells"},
# "relationship": "The ways in which some compounds fought the cancer cells were surprising"},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Molecular targets", "name": "previously overlooked molecular targets"},
# "relationship": "Most of these mechanisms involved interacting with previously overlooked molecular targets in the cancer cells."},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Proteins", "name": "activating other proteins or stabilizing interactions between proteins"},
# "relationship": "For example, some of the drugs did not inhibit proteins in cancer cells as expected, but instead fought the cancer by activating other proteins or stabilizing interactions between proteins."},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Molecular target", "name": "unknown target"},
# "relationship": "Tepoxalin, an anti-inflammatory compound, interacted with an unknown target"},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Protein", "name": "protein that otherwise strengthens cancer cells’ chemotherapy resistance"},
# "relationship": "Tepoxalin interacted with an unknown target to weaken the expression of a protein that otherwise strengthens cancer cells’ chemotherapy resistance."},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Usage", "name": "approved for treating osteoarthritis in dogs"},
# "relationship": "This compound was originally intended for use in humans but is currently approved for treating osteoarthritis in dogs."},
#
# {"node_1": {"label": "Cell-based approach", "name": "cell-based approach"},
# "node_2": {"label": "Interactions", "name": "surprising interactions"},
# "relationship": "The cell-based approach was able to expose these surprising interactions more readily than other research methods."},
#
# {"node_1": {"label": "Drugs", "name": "Drugs developed for treating diabetes"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs developed for treating diabetes were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Drugs", "name": "Drugs reducing inflammation"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs reducing inflammation were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Drugs", "name": "Drugs controlling alcohol use disorder"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs controlling alcohol use disorder were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Cancer Cell Line Encyclopedia", "name": "Cancer Cell Line Encyclopedia"},
# "node_2": {"label": "Mechanisms", "name": "comprehensive listing of the mechanisms by which each cancer cell line operates"},
# "relationship": "The cell line encyclopedia’s comprehensive listing of the mechanisms by which each cancer cell line operates enabled the team to predict which compounds could combat the lines most effectively."},
#
# {"node_1": {"label": "Disulfiram", "name": "Disulfiram"},
# "node_2": {"label": "Cell lines", "name": "cell lines with mutations"},
# "relationship": "Disulfiram attacked cell lines with mutations that depleted specific proteins called metallothioneins."},
#
# {"node_1": {"label": "Disulfiram", "name": "Disulfiram"},
# "node_2": {"label": "Usage", "name": "known as Antabuse, a drug that can support the treatment of alcohol use disorder"},
# "relationship": "One hope is that, going forward, each cell line’s cancer-causing mechanisms can serve as biomarkers, and that researchers will determine which drugs are especially good at targeting them. For example, disulfiram — also known as Antabuse, a drug that can support the treatment of alcohol use disorder — attacked cell lines with mutations that depleted specific proteins called metallothioneins."},
#
# {"node_1": {"label": "Genomic features", "name": "genomic features"},
# "node_2": {"label": "Drugs", "name": "drugs"},
# "relationship": "The genomic features gave us some initial hypotheses about how the drugs could be acting, which we can then take back to study in the lab. Our understanding of how these drugs kill cancer cells gives us a starting point for developing new therapies."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:45 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Drugs", "name": "approved, safe drugs"},
# "node_2": {"label": "Cancer", "name": "anticancer properties"},
# "relationship": "Some approved, safe drugs have unexpected anticancer properties."},
#
# {"node_1": {"label": "Drug", "name": "a drug developed to treat one condition"},
# "node_2": {"label": "Cancer", "name": "value in treating another"},
# "relationship": "Occasionally, researchers find that a drug developed to treat one condition has unexpected value in treating another."},
#
# {"node_1": {"label": "Drug", "name": "pain reliever aspirin"},
# "node_2": {"label": "Cancer", "name": "prevents cardiovascular disease"},
# "relationship": "A well-known case in point is the pain reliever aspirin, which turns out to be of use in preventing cardiovascular disease."},
#
# {"node_1": {"label": "Researchers", "name": "researchers"},
# "node_2": {"label": "Drug compounds", "name": "thousands of drug compounds"},
# "relationship": "Researchers have taken a fresh look at thousands of drug compounds"},
#
# {"node_1": {"label": "Drug compounds", "name": "nearly 50 approved drug compounds"},
# "node_2": {"label": "Cancer", "name": "cancer-fighting capabilities"},
# "relationship": "The investigation concludes that nearly 50 approved drug compounds have previously unrecognized cancer-fighting capabilities."},
#
# {"node_1": {"label": "Dr Todd Golub", "name": "Dr Todd Golub"},
# "node_2": {"label": "Cancer", "name": "anticipation of finding even a single compound with anticancer properties"},
# "relationship": "He is the senior investigator of the study, which is summarized in the journal Nature Cancer. He says, ‘We thought we’d be lucky if we found even a single compound with anticancer properties'"},
#
# {"node_1": {"label": "Broad Institute", "name": "The Broad Institute"},
# "node_2": {"label": "Drug Repurposing Hub", "name": "Drug Repurposing Hub"},
# "relationship": "The Broad Institute’s Drug Repurposing Hub is a massive database designed to help researchers find new uses for already approved compounds."},
#
# {"node_1": {"label": "Dr Steven Corsello", "name": "Dr Steven Corsello"},
# "node_2": {"label": "Drug Repurposing Hub", "name": "Drug Repurposing Hub"},
# "relationship": "The first author of the study, Dr Steven Corsello, the founder of the hub and an oncologist at Dana-Farber, says"},
#
# {"node_1": {"label": "Researchers", "name": "researchers"},
# "node_2": {"label": "Drug compounds", "name": "4,518 drugs"},
# "relationship": "The researchers tested 4,518 drugs"},
#
# {"node_1": {"label": "Drug compounds", "name": "578 human cancer cell lines"},
# "node_2": {"label": "Cancer Diagnosis Device/Tool", "name": "Cancer Cell Line Encyclopedia"},
# "relationship": "The researchers tested 4,518 drugs on 578 human cancer cell lines from the Broad Institute’s Cancer Cell Line Encyclopedia."},
#
# {"node_1": {"label": "Dr Golub's lab", "name": "Dr Golub's lab"},
# "node_2": {"label": "Molecular method", "name": "PRISM"},
# "relationship": "Dr Golub’s lab had developed a molecular method called PRISM"},
#
# {"node_1": {"label": "PRISM", "name": "PRISM"},
# "node_2": {"label": "Tissue used for cancer diagnosis", "name": "DNA barcode"},
# "relationship": "Dr Golub’s lab had developed a molecular method called PRISM that tags each cell line with a DNA barcode"},
#
# {"node_1": {"label": "DNA barcode", "name": "DNA barcode"},
# "node_2": {"label": "Cancer Diagnosis Method", "name": "pooling several cell lines in a single dish"},
# "relationship": "The barcodes sped up the testing by allowing the researchers to pool several cell lines in a single dish without losing the ability to track the survival rate of each as it reacted to a drug compound."},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Cancer", "name": "cancer cells"},
# "relationship": "The ways in which some compounds fought the cancer cells were surprising"},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Molecular targets", "name": "previously overlooked molecular targets"},
# "relationship": "Most of these mechanisms involved interacting with previously overlooked molecular targets in the cancer cells."},
#
# {"node_1": {"label": "Compounds", "name": "some compounds"},
# "node_2": {"label": "Proteins", "name": "activating other proteins or stabilizing interactions between proteins"},
# "relationship": "For example, some of the drugs did not inhibit proteins in cancer cells as expected, but instead fought the cancer by activating other proteins or stabilizing interactions between proteins."},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Molecular target", "name": "unknown target"},
# "relationship": "Tepoxalin, an anti-inflammatory compound, interacted with an unknown target"},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Protein", "name": "protein that otherwise strengthens cancer cells’ chemotherapy resistance"},
# "relationship": "Tepoxalin interacted with an unknown target to weaken the expression of a protein that otherwise strengthens cancer cells’ chemotherapy resistance."},
#
# {"node_1": {"label": "Tepoxalin", "name": "Tepoxalin"},
# "node_2": {"label": "Usage", "name": "approved for treating osteoarthritis in dogs"},
# "relationship": "This compound was originally intended for use in humans but is currently approved for treating osteoarthritis in dogs."},
#
# {"node_1": {"label": "Cell-based approach", "name": "cell-based approach"},
# "node_2": {"label": "Interactions", "name": "surprising interactions"},
# "relationship": "The cell-based approach was able to expose these surprising interactions more readily than other research methods."},
#
# {"node_1": {"label": "Drugs", "name": "Drugs developed for treating diabetes"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs developed for treating diabetes were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Drugs", "name": "Drugs reducing inflammation"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs reducing inflammation were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Drugs", "name": "Drugs controlling alcohol use disorder"},
# "node_2": {"label": "Cancer", "name": "potential use in treating cancer"},
# "relationship": "Drugs controlling alcohol use disorder were among those had potential use in treating cancer"},
#
# {"node_1": {"label": "Cancer Cell Line Encyclopedia", "name": "Cancer Cell Line Encyclopedia"},
# "node_2": {"label": "Mechanisms", "name": "comprehensive listing of the mechanisms by which each cancer cell line operates"},
# "relationship": "The cell line encyclopedia’s comprehensive listing of the mechanisms by which each cancer cell line operates enabled the team to predict which compounds could combat the lines most effectively."},
#
# {"node_1": {"label": "Disulfiram", "name": "Disulfiram"},
# "node_2": {"label": "Cell lines", "name": "cell lines with mutations"},
# "relationship": "Disulfiram attacked cell lines with mutations that depleted specific proteins called metallothioneins."},
#
# {"node_1": {"label": "Disulfiram", "name": "Disulfiram"},
# "node_2": {"label": "Usage", "name": "known as Antabuse, a drug that can support the treatment of alcohol use disorder"},
# "relationship": "One hope is that, going forward, each cell line’s cancer-causing mechanisms can serve as biomarkers, and that researchers will determine which drugs are especially good at targeting them. For example, disulfiram — also known as Antabuse, a drug that can support the treatment of alcohol use disorder — attacked cell lines with mutations that depleted specific proteins called metallothioneins."},
#
# {"node_1": {"label": "Genomic features", "name": "genomic features"},
# "node_2": {"label": "Drugs", "name": "drugs"},
# "relationship": "The genomic features gave us some initial hypotheses about how the drugs could be acting, which we can then take back to study in the lab. Our understanding of how these drugs kill cancer cells gives us a starting point for developing new therapies."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:45 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:54:45 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:55:00 - INFO
# Document: 4
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:55:00 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Include only specific type of cancer, for example, lymphocytic leukemia, breast cancer, etc. Do not include other diseases like diabetes, etc which are not cancer.'}, {'Cancer': 'Include when cancer is addressed in general without specification of any specific type of cancer such as breast cancer, leukemia, etc.'}, {'Biomarker for Cancer Diagnosis': 'Include only when using biomarkers for cancer diagnosis, otherwise do not include it'}, {'Tissue used for cancer diagnosis': 'Include only when using any tissue in cancer diagnosis. If the tissue is not involved in cancer diagnosis, do NOT include it. Tissue should be related to humans.'}, {'Tissue affected by cancer': 'Include only when human tissue is affected during cancer, otherwise do not include it'}, {'Cancer Diagnosis Method': 'Include only when a particular method is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Device/Tool': 'Include only when a device is used for cancer diagnosis, otherwise do not include it'}, {'Cancer Diagnosis Technology': 'Include only when a particular technology is used for cancer diagnosis, otherwise do not include it'}, {'Drugs': 'Include only when using drugs for cancer diagnosis, otherwise do not include it'}, {'New Research of Cancer Diagnosis Method': 'Include only when a new method or research is used/developed for cancer diagnosis. Do not include methods which not used in cancer diagnosis.'}] relationships=['Relation between any pair of Entities present in the text']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 29.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:55:34 - INFO
# LLM Response:
# [
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic mutations that drive specific cancers, biomarkers that predict disease risk or how well a person will respond to a particular treatment"
#        },
#        "relationship": "Biomarkers, such as genetic mutations that drive specific cancers and biomarkers that predict disease risk or how well a person will respond to a particular treatment, are used in cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "New Research of Cancer Diagnosis Method",
#            "name": "new therapies that seek to target the specific cellular pathway being exploited by a cancer"
#        },
#        "relationship": "New therapies are being developed to target the specific cellular pathway being exploited by a cancer, contributing to advances in cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "Tissue affected by cancer",
#            "name": "rare tumors"
#        },
#        "relationship": "Rare tumors are a type of cancer that occurs in fewer than 15 patients per 100,000 each year, and they are the focus of a study by Dr. Shumei Kato."
#    },
#    {
#        "node_1": {
#            "label": "Tissue affected by cancer",
#            "name": "rare tumors"
#        },
#        "node_2": {
#            "label": "Genetic mutations",
#            "name": "genetic mutations underpinning each tumor"
#        },
#        "relationship": "The study by Dr. Shumei Kato aimed to identify the genetic mutations underpinning each rare tumor."
#    },
#    {
#        "node_1": {
#            "label": "Genetic mutations",
#            "name": "genetic mutations underpinning each tumor"
#        },
#        "node_2": {
#            "label": "Cancer Diagnosis Method",
#            "name": "a therapy that was either designed for a different cancer or was in the clinical trial stage"
#        },
#        "relationship": "The genetic mutations underpinning each tumor were used to match 37 of the 40 study participants to a therapy that was either designed for a different cancer or was in the clinical trial stage."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "a therapy that was either designed for a different cancer or was in the clinical trial stage"
#        },
#        "node_2": {
#            "label": "Cancer Diagnosis Device/Tool",
#            "name": "not specified in the text"
#        },
#        "relationship": "A therapy that was either designed for a different cancer or was in the clinical trial stage was used as a cancer diagnosis method, but the specific device or tool is not mentioned in the text."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "a therapy that was either designed for a different cancer or was in the clinical trial stage"
#        },
#        "node_2": {
#            "label": "Tissue used for cancer diagnosis",
#            "name": "tumor tissue"
#        },
#        "relationship": "The cancer diagnosis method involved using tumor tissue to identify genetic mutations underpinning each tumor."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "a therapy that was either designed for a different cancer or was in the clinical trial stage"
#        },
#        "node_2": {
#            "label": "Drugs",
#            "name": "not specified in the text"
#        },
#        "relationship": "A therapy that was either designed for a different cancer or was in the clinical trial stage was used as a cancer diagnosis method, but the specific drugs are not mentioned in the text."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "new therapies that seek to target the specific cellular pathway being exploited by a cancer"
#        },
#        "node_2": {
#            "label": "Cancer Diagnosis Device/Tool",
#            "name": "not specified in the text"
#        },
#        "relationship": "New therapies that seek to target the specific cellular pathway being exploited by a cancer are being developed, but the specific device or tool is not mentioned in the text."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "new therapies that seek to target the specific cellular pathway being exploited by a cancer"
#        },
#        "node_2": {
#            "label": "Tissue used for cancer diagnosis",
#            "name": "tumor tissue"
#        },
#        "relationship": "New therapies that seek to target the specific cellular pathway being exploited by a cancer use tumor tissue to identify the cellular pathway."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Method",
#            "name": "new therapies that seek to target the specific cellular pathway being exploited by a cancer"
#        },
#        "node_2": {
#            "label": "Drugs",
#            "name": "not specified in the text"
#        },
#        "relationship": "New therapies that seek to target the specific cellular pathway being exploited by a cancer use drugs, but the specific drugs are not mentioned in the text."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "next-generation DNA sequencing"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic mutations that drive specific cancers"
#        },
#        "relationship": "Next-generation DNA sequencing is used to identify genetic mutations that drive specific cancers, which are biomarkers for cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "genomic profiling"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic driver events"
#        },
#        "relationship": "Genomic profiling is used to identify genetic driver events, which are biomarkers for cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "multi-omics profiling"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic makeup, gene expression, proteins, metabolism, and gut microflora"
#        },
#        "relationship": "Multi-omics profiling is used to analyze an individual’s genetic makeup, gene expression, proteins, metabolism, and gut microflora, which are biomarkers for cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "multi-omics profiling"
#        },
#        "node_2": {
#            "label": "Tissue used for cancer diagnosis",
#            "name": "tumor tissue, blood, and other bodily fluids"
#        },
#        "relationship": "Multi-omics profiling is used to analyze tumor tissue, blood, and other bodily fluids to identify biomarkers for cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "multi-omics profiling"
#        },
#        "node_2": {
#            "label": "Drugs",
#            "name": "not specified in the text"
#        },
#        "relationship": "Multi-omics profiling is used to analyze an individual’s genetic makeup, gene expression, proteins, metabolism, and gut microflora, but the specific drugs are not mentioned in the text."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "omics analyses"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic and epigenetic changes, tumor microenvironment, and metabolic and immunological changes"
#        },
#        "relationship": "A combination of omics analyses is used to identify genetic and epigenetic changes, tumor microenvironment, and metabolic and immunological changes, which are biomarkers for cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "omics analyses"
#        },
#        "node_2": {
#            "label": "Tissue used for cancer diagnosis",
#            "name": "tumor tissue"
#        },
#        "relationship": "Omics analyses are used to analyze tumor tissue to identify genetic and epigenetic changes, tumor microenvironment, and metabolic and immunological changes."
#    },
#    {
#        "node_1": {
#            "label": "Cancer Diagnosis Technology",
#            "name": "omics analyses"
#        },
#        "node_2": {
#            "label": "Drugs",
#            "name": "not specified in the text"
#        },
#        "relationship": "Omics analyses are used to identify genetic and epigenetic changes, tumor microenvironment, and metabolic and immunological changes, but the specific drugs are not mentioned in the text."
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:55:34 - INFO
# Trying JSON Parsing:
# [
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "Biomarker for Cancer Diagnosis",
#            "name": "genetic mutations that drive specific cancers, biomarkers that predict disease risk or how well a person will respond to a particular treatment"
#        },
#        "relationship": "Biomarkers, such as genetic mutations that drive specific cancers and biomarkers that predict disease risk or how well a person will respond to a particular treatment, are used in cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "New Research of Cancer Diagnosis Method",
#            "name": "new therapies that seek to target the specific cellular pathway being exploited by a cancer"
#        },
#        "relationship": "New therapies are being developed to target the specific cellular pathway being exploited by a cancer, contributing to advances in cancer diagnosis."
#    },
#    {
#        "node_1": {
#            "label": "Cancer",
#            "name": "cancer"
#        },
#        "node_2": {
#            "label": "Tissue affected by cancer",
#            "name": "rare tumors"
#        },
# ...
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "chlorogenic acid"
# }
# ,"relationship": "Chlorogenic acid is both a cancer diagnosis method and a biomarker for cancer diagnosis, as it may help lower blood sugar levels and reduce insulin spikes by reducing carbohydrate absorption in the digestive tract, and it may also boost fat metabolism, lower cholesterol and triglyceride levels, and improve obesity-related hormone levels."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Chlorogenic acid is used in cancer diagnosis by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Drugs", "name": "green coffee bean extract"
# }
# ,"relationship": "Green coffee bean extract is a cancer diagnosis method and a drug, as it contains chlorogenic acids and caffeine, which may have potential health benefits such as improving blood pressure and cholesterol levels, promoting weight loss, and providing antioxidants."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Green coffee bean extract is used in cancer diagnosis by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "chlorogenic acid"
# }
# ,"relationship": "Chlorogenic acid is both a cancer diagnosis technology and a biomarker for cancer diagnosis, as it may help lower blood sugar levels and reduce insulin spikes by reducing carbohydrate absorption in the digestive tract, and it may also boost fat metabolism, lower cholesterol and triglyceride levels, and improve obesity-related hormone levels."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Chlorogenic acid is used in cancer diagnosis technology by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Drugs", "name": "green coffee bean extract"
# }
# ,"relationship": "Green coffee bean extract is a cancer diagnosis technology and a drug, as it contains chlorogenic acids and caffeine, which may have potential health benefits such as improving blood pressure and cholesterol levels, promoting weight loss, and providing antioxidants."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Green coffee bean extract is used in cancer diagnosis technology by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract and chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract and chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:59:42 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Cancer", "name": "cancer"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "chlorogenic acids"
# }
# ,"relationship": "Chlorogenic acids, a group of antioxidant compounds found in green coffee bean extract, are believed to be responsible for potential health benefits such as improving blood pressure and cholesterol levels, which may be associated with cancer prevention or treatment."
# },
# {"node_1": {"label": "Cancer", "name": "cancer"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "caffeine"
# }
# ,"relationship": "Caffeine, found in green coffee bean extract, may help promote weight loss, which could potentially impact cancer prevention or treatment."
# },
# {"node_1": {"label": "Cancer", "name": "cancer"
# }
# ,"node_2": {"label": "Drugs", "name": "green coffee bean extract"
# }
# ,"relationship": "Green coffee bean extract, which contains chlorogenic acids and caffeine, may have potential health benefits such as improving blood pressure and cholesterol levels, promoting weight loss, and providing antioxidants, which could impact cancer prevention or treatment."
# },
# {"node_1": {"label": "Cancer", "name": "cancer"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer", "name": "cancer"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "chlorogenic acid"
# }
# ,"relationship": "Chlorogenic acid is both a cancer diagnosis method and a biomarker for cancer diagnosis, as it may help lower blood sugar levels and reduce insulin spikes by reducing carbohydrate absorption in the digestive tract, and it may also boost fat metabolism, lower cholesterol and triglyceride levels, and improve obesity-related hormone levels."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Chlorogenic acid is used in cancer diagnosis by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Drugs", "name": "green coffee bean extract"
# }
# ,"relationship": "Green coffee bean extract is a cancer diagnosis method and a drug, as it contains chlorogenic acids and caffeine, which may have potential health benefits such as improving blood pressure and cholesterol levels, promoting weight loss, and providing antioxidants."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Green coffee bean extract is used in cancer diagnosis by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Method", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Biomarker for Cancer Diagnosis", "name": "chlorogenic acid"
# }
# ,"relationship": "Chlorogenic acid is both a cancer diagnosis technology and a biomarker for cancer diagnosis, as it may help lower blood sugar levels and reduce insulin spikes by reducing carbohydrate absorption in the digestive tract, and it may also boost fat metabolism, lower cholesterol and triglyceride levels, and improve obesity-related hormone levels."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Chlorogenic acid is used in cancer diagnosis technology by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "chlorogenic acid"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Drugs", "name": "green coffee bean extract"
# }
# ,"relationship": "Green coffee bean extract is a cancer diagnosis technology and a drug, as it contains chlorogenic acids and caffeine, which may have potential health benefits such as improving blood pressure and cholesterol levels, promoting weight loss, and providing antioxidants."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"relationship": "Green coffee bean extract is used in cancer diagnosis technology by reducing carbohydrate absorption in the digestive tract."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Cancer Diagnosis Technology", "name": "green coffee bean extract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "liver"
# }
# ,"relationship": "Green coffee bean extract and chlorogenic acid may help protect the liver, which could be relevant in cancer treatment due to potential hepatotoxic effects of certain cancer therapies."
# },
# {"node_1": {"label": "Tissue used for cancer diagnosis", "name": "digestive tract"
# }
# ,"node_2": {"label": "Tissue affected by cancer", "name": "heart"
# }
# ,"relationship": "Green coffee bean extract and chlorogenic acid may help protect the heart, which could be relevant in cancer treatment due to potential cardiotoxic effects of certain cancer therapies."
# }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:59:42 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:59:42 - INFO
# Waiting for 15s before the next request ...
#
# INFO:__main__:Initialized KGOps with ontology and website name.
# INFO:__main__:Plotting the knowledge graph.
# INFO:__main__:Extracting labels from ontology.
# INFO:__main__:Generating color map for ontology labels.
# INFO:__main__:Color map generated successfully.
# INFO:__main__:Showing network graph and saving as knowledge_graph_cancer_biomarkers.html.
# INFO:__main__:Legend appended to the HTML file.
# Total number of Edges 216
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# knowledge_graph_cancer_biomarkers.html

# %%
ontology_ml = Ontology(
    labels=[
        {"Cancer Type": "Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer."},
        {"Cancer": "Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer."},
        {"Technology/Tool which uses ML": "Include only when a technology uses machine learning, otherwise do not include it."},
        {"Machine Learning method used": "Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it."},
        {"Healthcare problem solved by ML": "Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it."},
        {"Patient problem solved by ML": "Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc"},
        {"Cancer diagnosed by ML": "Include only when a cancer is diagnosed by machine learning, otherwise do not include it."},
        {"Disease diagnosed by ML": "Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it."},
    ],
    relationships=[
        "Relation between any pair of Entities",
        ],
)

# %%
current_time = str(datetime.datetime.now())

graph_maker_ml = GraphMaker(ontology=ontology_ml, llm_client=input_params.gen_client, verbose=False)

docs_ml = map(
    lambda t: Document(text=t, metadata={'generated_at': current_time}),
    df_ml_list
)

graph_ml = graph_maker_ml.from_documents(
    list(docs_ml),
    delay_s_between=15 ## delay_s_between because otherwise groq api maxes out pretty fast.
    )

print("Total number of Edges", len(graph_ml))

kg_ml = KGOps(ontology_ml, "knowledge_graph_healthcare_ml.html")
kg_ml.plot_knowledge_graph(graph_ml, notebook=True)
# Out:
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:38:51 - INFO
# Document: 1
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:38:51 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:38:53 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Machine Learning method used", "name": "deep learning algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict the onset of Alzheimer’s disease"},
# "relationship": "The input text mentions that deep learning algorithms can accurately predict the onset of Alzheimer’s disease as early as 6 years in advance."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "random forest, deep learning"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text states that researchers developed a system of learning algorithms using two models called 'random forest' and 'deep learning' to predict the risk of premature death due to chronic disease."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Cox regression, multivariate Cox model"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text mentions that the Cox regression model and the multivariate Cox model were used to predict the risk of premature death due to chronic disease."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "machine learning algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text states that machine learning algorithms were significantly more accurate in predicting death than the standard prediction models."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "machine learning, AI algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict heart disease risk"},
# "relationship": "The input text mentions that previous findings showed that certain AI algorithms are better at predicting heart disease risk than the conventional prediction models that cardiologists currently use."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "AI, machine learning"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict health outcomes"},
# "relationship": "The input text states that there is intense interest in the potential to use 'AI' or 'machine learning' to better predict health outcomes."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:38:53 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Machine Learning method used", "name": "deep learning algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict the onset of Alzheimer’s disease"},
# "relationship": "The input text mentions that deep learning algorithms can accurately predict the onset of Alzheimer’s disease as early as 6 years in advance."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "random forest, deep learning"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text states that researchers developed a system of learning algorithms using two models called 'random forest' and 'deep learning' to predict the risk of premature death due to chronic disease."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Cox regression, multivariate Cox model"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text mentions that the Cox regression model and the multivariate Cox model were used to predict the risk of premature death due to chronic disease."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "machine learning algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict premature death due to chronic disease"},
# "relationship": "The input text states that machine learning algorithms were significantly more accurate in predicting death than the standard prediction models."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "machine learning, AI algorithms"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict heart disease risk"},
# "relationship": "The input text mentions that previous findings showed that certain AI algorithms are better at predicting heart disease risk than the conventional prediction models that cardiologists currently use."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "AI, machine learning"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "predict health outcomes"},
# "relationship": "The input text states that there is intense interest in the potential to use 'AI' or 'machine learning' to better predict health outcomes."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:38:53 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:38:53 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:08 - INFO
# Document: 2
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:08 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:09 - INFO
# LLM Response:
# [
#    {
#        "node_1": {
#            "label": "Disease diagnosed by ML",
#            "name": "disease"
#        },
#        "node_2": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose a disease."
#    },
#    {
#        "node_1": {
#            "label": "Healthcare problem solved by ML",
#            "name": "diagnostic effectiveness"
#        },
#        "node_2": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "relationship": "The text states that deep learning algorithms were used to examine the diagnostic effectiveness of AI."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "sensitivity"
#        },
#        "relationship": "The text mentions that sensitivity, which is a measure of the probability that a diagnostic tool gets a positive result in people who have the disease, was examined for deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "specificity"
#        },
#        "relationship": "The text mentions that specificity, which is a measure of the accuracy of the diagnostic test, was examined for deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Cancer diagnosed by ML",
#            "name": "cancers"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose cancers."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Disease diagnosed by ML",
#            "name": "eye diseases"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose eye diseases."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "diagnostic performance"
#        },
#        "relationship": "The text states that AI, which uses machine learning, was used to examine the diagnostic performance of deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Cancer diagnosed by ML",
#            "name": "cancers"
#        },
#        "relationship": "The text mentions that AI, which uses machine learning, was used to diagnose cancers."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Disease diagnosed by ML",
#            "name": "eye diseases"
#        },
#        "relationship": "The text mentions that AI, which uses machine learning, was used to diagnose eye diseases."
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:10 - INFO
# Trying JSON Parsing:
# [
#    {
#        "node_1": {
#            "label": "Disease diagnosed by ML",
#            "name": "disease"
#        },
#        "node_2": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose a disease."
#    },
#    {
#        "node_1": {
#            "label": "Healthcare problem solved by ML",
#            "name": "diagnostic effectiveness"
#        },
#        "node_2": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "relationship": "The text states that deep learning algorithms were used to examine the diagnostic effectiveness of AI."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "sensitivity"
#        },
#        "relationship": "The text mentions that sensitivity, which is a measure of the probability that a diagnostic tool gets a positive result in people who have the disease, was examined for deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "specificity"
#        },
#        "relationship": "The text mentions that specificity, which is a measure of the accuracy of the diagnostic test, was examined for deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Cancer diagnosed by ML",
#            "name": "cancers"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose cancers."
#    },
#    {
#        "node_1": {
#            "label": "Machine Learning method used",
#            "name": "deep learning algorithms"
#        },
#        "node_2": {
#            "label": "Disease diagnosed by ML",
#            "name": "eye diseases"
#        },
#        "relationship": "The text mentions that deep learning algorithms were used to diagnose eye diseases."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Healthcare problem solved by ML",
#            "name": "diagnostic performance"
#        },
#        "relationship": "The text states that AI, which uses machine learning, was used to examine the diagnostic performance of deep learning algorithms."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Cancer diagnosed by ML",
#            "name": "cancers"
#        },
#        "relationship": "The text mentions that AI, which uses machine learning, was used to diagnose cancers."
#    },
#    {
#        "node_1": {
#            "label": "Technology/Tool which uses ML",
#            "name": "AI"
#        },
#        "node_2": {
#            "label": "Disease diagnosed by ML",
#            "name": "eye diseases"
#        },
#        "relationship": "The text mentions that AI, which uses machine learning, was used to diagnose eye diseases."
#    }
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:10 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:10 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:25 - INFO
# Document: 3
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:25 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:26 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Mental health issue screening"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology uses machine learning to screen for changes in mental health by monitoring the mental health of participants for up to 14 months using a specially designed application that the participants were able to access by calling a toll-free number."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "node_2": {"label": "Machine Learning method used", "name": "Keyword and voice pattern analysis"},
# "relationship": "The technology uses machine learning to identify and analyze keywords and voice patterns for each person who calls in."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Speaking more freely"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology allows patients to speak more freely as they are speaking to a computer-generated voice."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Feeling less lonely"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology helps patients feel less lonely as they know that someone would be listening to it, and to them that meant that someone cared."},
#
# {"node_1": {"label": "Cancer", "name": "N/A"},
# "node_2": {"label": "Cancer", "name": "N/A"},
# "relationship": "The text does not mention any cancer-related information."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:26 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Mental health issue screening"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology uses machine learning to screen for changes in mental health by monitoring the mental health of participants for up to 14 months using a specially designed application that the participants were able to access by calling a toll-free number."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "node_2": {"label": "Machine Learning method used", "name": "Keyword and voice pattern analysis"},
# "relationship": "The technology uses machine learning to identify and analyze keywords and voice patterns for each person who calls in."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Speaking more freely"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology allows patients to speak more freely as they are speaking to a computer-generated voice."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Feeling less lonely"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Interactive voice recognition technology"},
# "relationship": "The technology helps patients feel less lonely as they know that someone would be listening to it, and to them that meant that someone cared."},
#
# {"node_1": {"label": "Cancer", "name": "N/A"},
# "node_2": {"label": "Cancer", "name": "N/A"},
# "relationship": "The text does not mention any cancer-related information."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:26 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:26 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:41 - INFO
# Document: 4
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:41 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:43 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Diagnosis of mental and physical conditions"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Smart speakers"},
# "relationship": "Smart speakers may soon be able to diagnose our mental and physical conditions using machine learning."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Understanding a person's emotional state"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Smart speakers"},
# "relationship": "Smart speakers can potentially predict a person's emotional response by analyzing skin conductance and pupillary dilation."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Tracking cognitive processes"},
# "node_2": {"label": "Machine Learning method used", "name": "Pupillometry"},
# "relationship": "Pupillometry, a machine learning method, can track cognitive processes such as memory, attention, and mental load by examining the behavior and measuring the diameter of our pupils."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Predicting emotional responses"},
# "node_2": {"label": "Machine Learning method used", "name": "Skin conductance analysis"},
# "relationship": "Skin conductance analysis, also known as galvanic skin response, can predict a person's emotional response when watching a movie or a football match."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Understanding a person's emotional state"},
# "node_2": {"label": "Machine Learning method used", "name": "Carbon dioxide tracking"},
# "relationship": "Carbon dioxide tracking can predict a person's emotional state, such as loneliness or fear."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Simulating vision problems"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "A pair of glasses"},
# "relationship": "A pair of glasses can simulate vision problems to understand the user's experience."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Understanding the experience of living with eye diseases"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Virtual reality simulators"},
# "relationship": "Virtual reality simulators can recreate the experience of living with age-related macular degeneration, glaucoma, protanopia, and diabetic retinopathy."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Gathering patient data for personalized therapies"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Empathetic technology"},
# "relationship": "Empathetic technology, combined with machine learning and sensing technology, can gather vast amounts of data about patients for personalized therapies."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Optimizing physical therapy rehabilitation"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Orthopedic surgeon's data gathering"},
# "relationship": "Orthopedic surgeons can gather data about a patient's gait and knee usage before surgery using empathetic technology for optimized physical therapy rehabilitation."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:43 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Diagnosis of mental and physical conditions"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Smart speakers"},
# "relationship": "Smart speakers may soon be able to diagnose our mental and physical conditions using machine learning."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Understanding a person's emotional state"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Smart speakers"},
# "relationship": "Smart speakers can potentially predict a person's emotional response by analyzing skin conductance and pupillary dilation."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Tracking cognitive processes"},
# "node_2": {"label": "Machine Learning method used", "name": "Pupillometry"},
# "relationship": "Pupillometry, a machine learning method, can track cognitive processes such as memory, attention, and mental load by examining the behavior and measuring the diameter of our pupils."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Predicting emotional responses"},
# "node_2": {"label": "Machine Learning method used", "name": "Skin conductance analysis"},
# "relationship": "Skin conductance analysis, also known as galvanic skin response, can predict a person's emotional response when watching a movie or a football match."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Understanding a person's emotional state"},
# "node_2": {"label": "Machine Learning method used", "name": "Carbon dioxide tracking"},
# "relationship": "Carbon dioxide tracking can predict a person's emotional state, such as loneliness or fear."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Simulating vision problems"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "A pair of glasses"},
# "relationship": "A pair of glasses can simulate vision problems to understand the user's experience."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Understanding the experience of living with eye diseases"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Virtual reality simulators"},
# "relationship": "Virtual reality simulators can recreate the experience of living with age-related macular degeneration, glaucoma, protanopia, and diabetic retinopathy."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Gathering patient data for personalized therapies"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Empathetic technology"},
# "relationship": "Empathetic technology, combined with machine learning and sensing technology, can gather vast amounts of data about patients for personalized therapies."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Optimizing physical therapy rehabilitation"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Orthopedic surgeon's data gathering"},
# "relationship": "Orthopedic surgeons can gather data about a patient's gait and knee usage before surgery using empathetic technology for optimized physical therapy rehabilitation."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:43 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:43 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:39:58 - INFO
# Document: 5
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:39:58 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 1.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:40:00 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Disease diagnosed by ML", "name": "Hypoglycemia"},
# "node_2": {"label": "Machine Learning method used", "name": "AI system"},
# "relationship": "The AI system is used to automatically detect hypoglycemia."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Difficulty in measuring glucose levels"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Inconvenience in measuring glucose levels"},
# "relationship": "The AI system is designed to improve treatments for specific health issues related to measuring glucose levels, making it easier for patients."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "New AI technology"},
# "relationship": "The AI system is a part of the new AI technology developed at the University of Warwick."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "None"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "Hypoglycemia"},
# "relationship": "The AI system diagnoses hypoglycemia, not cancer."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "New AI technology"},
# "node_2": {"label": "Cancer Type", "name": "None"},
# "relationship": "The new AI technology is not specifically designed for any type of cancer."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Nocturnal hypoglycemia detection"},
# "relationship": "The AI system is used to automatically detect nocturnal hypoglycemia."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Real-time alarm for hypoglycemia"},
# "relationship": "The AI system could result in a real-time alarm system that alerts individuals if their blood sugar levels change dramatically."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:00 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Disease diagnosed by ML", "name": "Hypoglycemia"},
# "node_2": {"label": "Machine Learning method used", "name": "AI system"},
# "relationship": "The AI system is used to automatically detect hypoglycemia."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Difficulty in measuring glucose levels"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Inconvenience in measuring glucose levels"},
# "relationship": "The AI system is designed to improve treatments for specific health issues related to measuring glucose levels, making it easier for patients."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "New AI technology"},
# "relationship": "The AI system is a part of the new AI technology developed at the University of Warwick."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "None"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "Hypoglycemia"},
# "relationship": "The AI system diagnoses hypoglycemia, not cancer."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "New AI technology"},
# "node_2": {"label": "Cancer Type", "name": "None"},
# "relationship": "The new AI technology is not specifically designed for any type of cancer."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Nocturnal hypoglycemia detection"},
# "relationship": "The AI system is used to automatically detect nocturnal hypoglycemia."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI system"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Real-time alarm for hypoglycemia"},
# "relationship": "The AI system could result in a real-time alarm system that alerts individuals if their blood sugar levels change dramatically."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:00 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:00 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:15 - INFO
# Document: 6
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:40:15 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 15.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:40:32 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Prediction of future risk of developing psychosis"},
# "node_2": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "relationship": "A machine-learning technique was used to analyze language in a group of at-risk young people and predict which individuals would go on to develop psychosis with an accuracy of 93%."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Machine learning system"},
# "relationship": "The machine-learning technique was implemented on a machine learning system that looked for patterns in a known set of data and learned to identify specific features."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Identification of subtle patterns in people's use of language"},
# "relationship": "The machine-learning technique was used to spot patterns in people's use of language that even doctors may not notice, like a microscope for warning signs of psychosis."},
#
# {"node_1": {"label": "Cancer", "name": "Psychosis"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "Psychosis"},
# "relationship": "The machine-learning technique was used to diagnose psychosis in at-risk young people."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Establishment of language norms of everyday conversation"},
# "node_2": {"label": "Machine Learning method used", "name": "Word2Vec software"},
# "relationship": "The machine-learning system used Word2Vec software to analyze individual words in the conversation and map words so that those with similar meanings were near each other in semantic space."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Word2Vec software"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Machine learning system"},
# "relationship": "The Word2Vec software was used as a part of the machine learning system to extend its ability to analyze semantics."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Improvement of doctors' ability to diagnose young people at risk of developing psychosis"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Understanding of the reasons for psychosis"},
# "relationship": "The North American Prodrome Longitudinal Study (NAPLS) aims to improve doctors' ability to diagnose young people who might be at risk of psychosis and understand the reasons."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Early identification of individuals at risk of psychosis"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Use of preventive interventions"},
# "relationship": "If individuals at risk of psychosis can be identified earlier, preventive interventions can be used to delay onset and perhaps even reduce the occurrence of psychosis."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:32 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Prediction of future risk of developing psychosis"},
# "node_2": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "relationship": "A machine-learning technique was used to analyze language in a group of at-risk young people and predict which individuals would go on to develop psychosis with an accuracy of 93%."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Machine learning system"},
# "relationship": "The machine-learning technique was implemented on a machine learning system that looked for patterns in a known set of data and learned to identify specific features."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Machine learning technique"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Identification of subtle patterns in people's use of language"},
# "relationship": "The machine-learning technique was used to spot patterns in people's use of language that even doctors may not notice, like a microscope for warning signs of psychosis."},
#
# {"node_1": {"label": "Cancer", "name": "Psychosis"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "Psychosis"},
# "relationship": "The machine-learning technique was used to diagnose psychosis in at-risk young people."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Establishment of language norms of everyday conversation"},
# "node_2": {"label": "Machine Learning method used", "name": "Word2Vec software"},
# "relationship": "The machine-learning system used Word2Vec software to analyze individual words in the conversation and map words so that those with similar meanings were near each other in semantic space."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Word2Vec software"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "Machine learning system"},
# "relationship": "The Word2Vec software was used as a part of the machine learning system to extend its ability to analyze semantics."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Improvement of doctors' ability to diagnose young people at risk of developing psychosis"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Understanding of the reasons for psychosis"},
# "relationship": "The North American Prodrome Longitudinal Study (NAPLS) aims to improve doctors' ability to diagnose young people who might be at risk of psychosis and understand the reasons."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Early identification of individuals at risk of psychosis"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Use of preventive interventions"},
# "relationship": "If individuals at risk of psychosis can be identified earlier, preventive interventions can be used to delay onset and perhaps even reduce the occurrence of psychosis."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:32 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:32 - INFO
# Waiting for 15s before the next request ...
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:40:47 - INFO
# Document: 7
#
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:40:47 - INFO
# Using Ontology:
# labels=[{'Cancer Type': 'Specific type of cancer, for example, leukemia, breast cancer, etc. Do not include any other disease except cancer.'}, {'Cancer': 'Include only when cancer is addressed in general without specifying any particular type of cancer such as breast cancer, leukemia, etc. Do not include any other disease except cancer.'}, {'Technology/Tool which uses ML': 'Include only when a technology uses machine learning, otherwise do not include it.'}, {'Machine Learning method used': 'Include only when machine learning method is used to solve a problem or identify a disease, otherwise do not include it.'}, {'Healthcare problem solved by ML': 'Include only when a problem is solved by machine learning. Do not add a problem if it is not solved by machine learning, otherwise do not include it.'}, {'Patient problem solved by ML': 'Include only when a patient problem which is solved by machine learning like delays in getting the report, time taken was longer previously, quick diagnosis, etc'}, {'Cancer diagnosed by ML': 'Include only when a cancer is diagnosed by machine learning, otherwise do not include it.'}, {'Disease diagnosed by ML': 'Include only when a disease other than cancer is diagnosed by machine learning, otherwise do not include it.'}] relationships=['Relation between any pair of Entities']
# Using Model:  mixtral-8x7b-32768
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 429 Too Many Requests"
# INFO:groq._base_client:Retrying request to /openai/v1/chat/completions in 13.000000 seconds
# INFO:httpx:HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
#
# ▶︎ GRAPH MAKER VERBOSE - 2024-09-23 07:41:03 - INFO
# LLM Response:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "node_2": {"label": "Machine Learning method used", "name": "Artificial Intelligence (AI)"},
# "relationship": "The text mentions the use of AI in predicting how well a person with depression will respond to medication."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "node_2": {"label": "Patient problem solved by ML", "name": "Delays in getting the report, time taken was longer previously, quick diagnosis, etc."},
# "relationship": "The healthcare problem of depression medication response prediction is linked to the patient problem of quick diagnosis and reducing delays in getting the report."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "Depression"},
# "relationship": "The healthcare problem being addressed is the diagnosis of depression, which is a type of cancer according to the given ontology."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Artificial Intelligence (AI)"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "AI-assisted analysis"},
# "relationship": "The machine learning method used is AI, which is a technology used for analyzing brain scans to predict depression medication response."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "AI-assisted analysis"},
# "node_2": {"label": "Machine Learning method used", "name": "Machine Learning"},
# "relationship": "The technology used is AI-assisted analysis, which is a type of machine learning method."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "Machine Learning"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "relationship": "Machine learning is used to solve the healthcare problem of depression medication response prediction."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "Delays in getting the report, time taken was longer previously, quick diagnosis, etc."},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "relationship": "The patient problem of quick diagnosis and reducing delays in getting the report is addressed by the healthcare problem of depression medication response prediction."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "Depression"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "relationship": "The cancer of depression is diagnosed by the healthcare problem of depression medication response prediction."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:41:03 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# "node_2": {"label": "Machine Learning method used", "name": "Artificial Intelligence (AI)"},
# "relationship": "The text mentions the use of AI in predicting how well a person with depression will respond to medication."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "Depression medication response prediction"},
# ...
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:46:54 - INFO
# Trying JSON Parsing:
# [
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The genetic study used machine learning and statistical methods, including a genome-wide association study, to examine the genetic data of individuals and identify risk factors for varicose veins."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study applied machine learning and statistical methods to determine the risk of developing varicose veins based on a person's genetic data."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The study focused on varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study focused on varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The machine learning methods used in the study did not focus on any type of cancer."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The machine learning methods used in the study did not focus on cancer in general."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The machine learning methods used in the study aimed to solve the healthcare problem of varicose veins."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The machine learning methods used in the study aimed to determine the risk of developing varicose veins for patients."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The machine learning methods used in the study did not diagnose any disease other than varicose veins."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The machine learning methods used in the study did not diagnose cancer."},
#
# {"node_1": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The study focused on determining the risk of developing varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study focused on determining the risk of developing varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study aimed to determine the risk of developing varicose veins for patients."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study did not focus on any type of cancer or cancer in general."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study focused on varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The machine learning methods used in the study did not focus on any type of cancer."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study focused on determining the risk of developing varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer Type", "name": "not applicable"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study focused on varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The machine learning methods used in the study did not focus on cancer in general."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study focused on determining the risk of developing varicose veins, which is not a type of cancer."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer", "name": "not applicable"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The study did not diagnose any type of cancer using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study focused on varicose veins and did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The machine learning methods used in the study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study focused on determining the risk of developing varicose veins and did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The study did not diagnose any type of cancer using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study focused on varicose veins and did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The machine learning methods used in the study did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study focused on determining the risk of developing varicose veins and did not diagnose cancer using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not diagnose any disease other than varicose veins using machine learning."},
#
# {"node_1": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "node_2": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Cancer Type", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Cancer", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Healthcare problem solved by ML", "name": "varicose veins"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Machine Learning method used", "name": "genome-wide association study, machine learning, and statistical methods"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Patient problem solved by ML", "name": "determine the risk of developing varicose veins"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Disease diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."},
#
# {"node_1": {"label": "Technology/Tool which uses ML", "name": "not applicable"},
# "node_2": {"label": "Cancer diagnosed by ML", "name": "not applicable"},
# "relationship": "The study did not mention any specific technology or tool that uses machine learning."}
# ]
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:46:54 - INFO
# JSON Parsing Successful!
#
#
# ▶︎ GRAPH MAKER LOG - 2024-09-23 07:46:54 - INFO
# Waiting for 15s before the next request ...
#
# INFO:__main__:Initialized KGOps with ontology and website name.
# INFO:__main__:Plotting the knowledge graph.
# INFO:__main__:Extracting labels from ontology.
# INFO:__main__:Generating color map for ontology labels.
# INFO:__main__:Color map generated successfully.
# INFO:__main__:Showing network graph and saving as knowledge_graph_healthcare_ml.html.
# Total number of Edges 194
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# knowledge_graph_healthcare_ml.html
# INFO:__main__:Legend appended to the HTML file.
